# %% [markdown]
# # Portfolio Simulation Modeling

# %% [markdown]
# ## Download Data
# #### Download S&P 500 index data from Yahoo Finance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as datetime
from numpy import *
# %matplotlib inline

# %%
try:
    import pandas_datareader.data as web
except:
    # !pip install pandas_datareader
    import pandas_datareader.data as web

# %%
try:
    import yfinance as yf
except:
    # !pip install yfinance
    import yfinance as yf

# %% [markdown]
# Set start date, end date and data source ('Yahoo Finance', 'Quandl', etc.) if using `pandas_datareader` or use `yfinance`. Download S&P 500 index data from Yahoo Finance.

# %%
start_date = datetime.date(1992,1,1)
end_date = datetime.date(2023,1,1)
# Download S&P 500 index data
#SnP500_Ddata = web.DataReader('^GSPC','yahoo',start_date,end_date) # pandas_datareader
SnP500_Ddata = yf.download('^GSPC', start=start_date, end=end_date, progress=False) # yfinance
SnP500_Ddata.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1992-01-02  417.029999  417.269989  411.040009  417.260010  417.260010
# 1992-01-03  417.269989  419.790009  416.160004  419.339996  419.339996
# 1992-01-06  419.309998  419.440002  416.920013  417.959991  417.959991
# 1992-01-07  417.959991  417.959991  415.200012  417.399994  417.399994
# 1992-01-08  417.359985  420.230011  415.019989  418.100006  418.100006
#
#                Volume
# Date
# 1992-01-02  207570000
# 1992-01-03  224270000
# 1992-01-06  251210000
# 1992-01-07  252780000
# 1992-01-08  290750000

# %% [markdown]
# #### Transform daily data into annual data:

# %%
# Create a time-series of annual data points from daily data
SnP500_Adata = SnP500_Ddata.resample('A').last()
SnP500_Adata[['Volume','Adj Close']].tail()
# Out:
#                 Volume    Adj Close
# Date
# 2018-12-31  3461920000  2506.850098
# 2019-12-31  2894760000  3230.780029
# 2020-12-31  3179040000  3756.070068
# 2021-12-31  2677820000  4766.180176
# 2022-12-31  2979870000  3839.500000

# %% [markdown]
# #### Compute annual return of S&P 500 index:

# %%
SnP500_Adata[['Adj Close']] = SnP500_Adata[['Adj Close']].apply(pd.to_numeric, errors='ignore')
SnP500_Adata['returns'] = SnP500_Adata['Adj Close'] / SnP500_Adata['Adj Close'].shift(1) -1
SnP500_Adata = SnP500_Adata.dropna()
print (SnP500_Adata['returns'])
# Out:
# Date
# 1993-12-31    0.070552
# 1994-12-31   -0.015393
# 1995-12-31    0.341107
# 1996-12-31    0.202637
# 1997-12-31    0.310082
# 1998-12-31    0.266686
# 1999-12-31    0.195260
# 2000-12-31   -0.101392
# 2001-12-31   -0.130427
# 2002-12-31   -0.233660
# 2003-12-31    0.263804
# 2004-12-31    0.089935
# 2005-12-31    0.030010
# 2006-12-31    0.136194
# 2007-12-31    0.035296
# 2008-12-31   -0.384858
# 2009-12-31    0.234542
# 2010-12-31    0.127827
# 2011-12-31   -0.000032
# 2012-12-31    0.134057
# 2013-12-31    0.296012
# 2014-12-31    0.113906
# 2015-12-31   -0.007266
# 2016-12-31    0.095350
# 2017-12-31    0.194200
# 2018-12-31   -0.062373
# 2019-12-31    0.288781
# 2020-12-31    0.162589
# 2021-12-31    0.268927
# 2022-12-31   -0.194428
# Freq: A-DEC, Name: returns, dtype: float64

# %% [markdown]
# #### Compute average annual return and standard deviation of return for S&P 500 index:

# %%
SnP500_mean_ret = float(SnP500_Adata[['returns']].mean())
SnP500_std_ret = float(SnP500_Adata[['returns']].std())
print ("S&P 500 average return = %g%%, st. dev  = %g%%" % (100*SnP500_mean_ret, 100*SnP500_std_ret))
# Out:
# S&P 500 average return = 9.09309%, st. dev  = 17.7042%

# %% [markdown]
# ## Simulation Example 1

# %% [markdown]
# We want to invest $\$$1000 in the US stock market for 1 year: $v_0 = 1000$

# %%
v0 = 1000 # Initial capital

# %% [markdown]
# In our example we assume that the return of the market over the next year follow Normal distribution.
#
# Between 1992 and 2022, S&P 500 returned 9.09% per year on average with a standard deviation of 17.70%.
#
# Generate 100 scenarios for the market return over the next year (draw 100 random numbers from a Normal distribution with mean 9.89% and standard deviation of 16.90%):

# %%
Ns = 100 # Number of scenarios
r01 = random.normal(SnP500_mean_ret, SnP500_std_ret, Ns)
r01
# Out:
# array([ 0.22223722,  0.05321384,  0.42678197, -0.15731629,  0.39870384,
#         0.17531068, -0.14033132,  0.38016179,  0.13199367, -0.11313085,
#         0.08634191,  0.19987892, -0.06285282,  0.06328223,  0.15145386,
#        -0.04827297,  0.02201731, -0.11327395,  0.08290985, -0.06414826,
#         0.19021959,  0.18114644, -0.16492255,  0.01125508,  0.17250029,
#         0.21415356,  0.09321996, -0.22518917, -0.12792041, -0.0372846 ,
#         0.1700335 ,  0.1020933 ,  0.16928562,  0.0635376 ,  0.06867574,
#         0.45475201,  0.12884318, -0.0377961 ,  0.27542843, -0.09951161,
#         0.41168092,  0.15070202,  0.13204489,  0.21390182, -0.35942668,
#         0.05400507,  0.08803794, -0.04412574,  0.23106134,  0.11478342,
#         0.24711813, -0.10010238,  0.0971567 ,  0.09177965, -0.07696345,
#         0.07186136,  0.02479921,  0.07696149,  0.20123639,  0.04435247,
#         0.12003942, -0.04690794, -0.24053997,  0.17713702, -0.19952438,
#         0.17962503,  0.13580737,  0.32687365, -0.15950274,  0.12725272,
#         0.08824936, -0.03366746, -0.06811264, -0.13527428,  0.02247835,
#        -0.24800285, -0.12881934,  0.07118375,  0.13803217, -0.00457207,
#         0.11864903,  0.11865482, -0.05820818,  0.24174535,  0.18717202,
#         0.35044962,  0.23476111,  0.32208142,  0.25057158,  0.21034367,
#        -0.04445849,  0.2460652 ,  0.00641109,  0.180958  ,  0.17145286,
#         0.04302001,  0.3368825 ,  0.03565666, -0.12085148,  0.30446349])

# %% [markdown]
# Value of investment at the end of year 1:
# $v_1 = v_0 + r_{0,1}\cdot v_0 = (1 + r_{0,1})\cdot v_0$

# %%
# Distribution of value at the end of year 1
v1 = (r01 + 1) * v0
v1
# Out:
# array([1222.23722488, 1053.21383624, 1426.78196932,  842.68371164,
#        1398.70383943, 1175.3106781 ,  859.66868244, 1380.16178623,
#        1131.99366798,  886.86914749, 1086.34191291, 1199.8789164 ,
#         937.14718251, 1063.28222527, 1151.4538639 ,  951.72703407,
#        1022.01730747,  886.726048  , 1082.90984843,  935.85173676,
#        1190.21959075, 1181.14643882,  835.0774517 , 1011.25508041,
#        1172.50029255, 1214.15355952, 1093.21996262,  774.81083062,
#         872.07958767,  962.71540323, 1170.03350359, 1102.09329836,
#        1169.28562111, 1063.53760253, 1068.67574208, 1454.75201004,
#        1128.84317816,  962.20390211, 1275.42842944,  900.48838533,
#        1411.6809227 , 1150.70202302, 1132.04488721, 1213.90182404,
#         640.57332326, 1054.00506925, 1088.03794099,  955.87426465,
#        1231.0613424 , 1114.78341594, 1247.11812995,  899.89761986,
#        1097.15669871, 1091.77965062,  923.03654672, 1071.86135655,
#        1024.7992068 , 1076.96149113, 1201.23638639, 1044.35246812,
#        1120.03941572,  953.09205731,  759.46002647, 1177.13701965,
#         800.47561645, 1179.62502506, 1135.80737483, 1326.87364901,
#         840.49726247, 1127.25272319, 1088.24935547,  966.33253848,
#         931.88736004,  864.72572126, 1022.47834951,  751.99714548,
#         871.18066449, 1071.18374847, 1138.03216715,  995.42793243,
#        1118.64902921, 1118.65481799,  941.79182209, 1241.74534549,
#        1187.17201874, 1350.44962111, 1234.76110616, 1322.08141899,
#        1250.57157775, 1210.34366986,  955.54151291, 1246.06519941,
#        1006.41109457, 1180.95799715, 1171.45286012, 1043.02001389,
#        1336.88249669, 1035.65665984,  879.14852331, 1304.46349161])

# %% [markdown]
# #### Compute statistical measures from the distribution

# %% [markdown]
# Mean:

# %%
mean(v1)
# Out:
# 1082.2592048827348

# %% [markdown]
# Standard deviation:

# %%
std(v1)
# Out:
# 163.17274980769258

# %% [markdown]
# Minimum, maximum:

# %%
min(v1), max(v1)
# Out:
# (640.5733232559354, 1454.7520100429324)

# %% [markdown]
# #### Compute percentiles/quantiles
#
# 5th percentile, median, 95th percentile:

# %%
percentile(v1, [5, 50,95])
# Out:
# array([ 833.34735994, 1090.01450305, 1351.93522936])

# %%
sortedScen = sorted(v1)   # sort scenarios
mean(sortedScen[4:6]), mean(sortedScen[49:51]), mean(sortedScen[94:96])
# Out:
# (817.7765340755095, 1090.0145030463555, 1365.3057036700657)

# %% [markdown]
# Alternative way to compute percentiles/quantiles

# %%
sortedScen[int(Ns-(1-0.05)*Ns)-1] #  5th percentile
# Out:
# 800.4756164531353

# %%
# Alternative way to compute percentiles/quantiles
sortedScen[int(Ns-(1-0.95)*Ns)-1] #  95th percentile
# Out:
# 1350.449621105696

# %% [markdown]
# #### Visualize results
#
# Plot a histogram of the distribution of outcomes for v1:

# %%
hist, bins = histogram(v1)
positions = (bins[:-1] + bins[1:]) / 2
plt.bar(positions, hist, width=60)
plt.xlabel('portfolio value in 1 year')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# Simulated paths over time:

# %%
# Plot simulated paths over time
for res in v1:
    plt.plot((0,1), (v0, res))
plt.xlabel('time step')
plt.ylabel('portfolio value')
plt.title('Simulated Value Paths')
plt.show()

# %% [markdown]
# # Simulation Example 2

# %% [markdown]
# You are planning for retirement and decide to invest in the market for the next 30 years (instead of only the next year as in example 1).
#
# Assume that every year your investment returns from investing into the        S&P 500 will follow a Normal distribution with the mean and standard deviation as in example 1.
#
# Your initial capital is still \$1000

# %%
v0 = 1000 # Initial capital

# %% [markdown]
# Between 1992 and 2022, S&P 500 returned 9.09% per year on average with a standard deviation of 17.70%.
#
# Simulate 30 columns of 100 observations each of single period returns:

# %%
r_speriod30  = random.normal(SnP500_mean_ret, SnP500_std_ret, (Ns, 30))
r_speriod30
# Out:
# array([[ 0.22149387, -0.05688013, -0.0951898 , ...,  0.12162785,
#          0.17128529, -0.17539645],
#        [-0.06810093,  0.51849096,  0.24144153, ...,  0.24813369,
#         -0.11898366, -0.00335435],
#        [-0.1237247 ,  0.11800565, -0.11284664, ...,  0.09522947,
#          0.36313946,  0.08401797],
#        ...,
#        [-0.12397726,  0.15705039,  0.19886376, ...,  0.07990496,
#          0.1470735 ,  0.14544888],
#        [ 0.06986285,  0.22454784,  0.02537558, ...,  0.38030061,
#          0.28082465,  0.08888184],
#        [ 0.2302583 ,  0.00692955,  0.08525746, ...,  0.10227116,
#          0.19898267,  0.20984722]])

# %% [markdown]
# Compute and plot $v_{30}$

# %%
v30 = prod(1 + r_speriod30 , 1) * v0

hist, bins = histogram(v30)
positions = (bins[:-1] + bins[1:]) / 2
width = (bins[1] - bins[0]) * 0.8
plt.bar(positions, hist, width=width)
plt.xlabel('portfolio value after 30 years')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# Simulated paths over time:

# %%
for scenario in r_speriod30:
    y = [prod(1 + scenario[0:i]) * v0 for i in range(0,31)]
    plt.plot(range(0,31), y)
plt.xlabel('time step')
plt.ylabel('portfolio value')
plt.title('Simulated Value Paths')
plt.show()

# %% [markdown]
# #### Compute percentiles/quantiles
#
# 5th percentile, median, 95th percentile:

# %%
percentile(v30, [5, 50,95])
# Out:
# array([ 1722.23206811,  9792.30023408, 44891.17106419])

# %%
sortedScen = sorted(v30)   # sort scenarios
sortedScen[int(Ns-(1-0.05)*Ns)-1], sortedScen[int(Ns-(1-0.95)*Ns)-1]
# Out:
# (1664.244050985217, 44754.096701966504)

# %% [markdown]
# ## Simulation Example 3
# #### Download US Treasury bill data from Federal Reserve:

# %%
# Download 3-month T-bill rates from Federal Reserve
start_date_b = datetime.date(1993,1,1)
end_date_b = datetime.date(2023,1,1)
TBill_Ddata = web.DataReader('DTB3','fred',start_date_b,end_date_b)
TBill_Ddata.head()
# Out:
#             DTB3
# DATE
# 1993-01-01   NaN
# 1993-01-04  3.08
# 1993-01-05  3.11
# 1993-01-06  3.10
# 1993-01-07  3.12

# %% [markdown]
# #### Transform daily data into annual data:

# %%
# Create a time-series of annual data points from daily data
TBill_Adata = TBill_Ddata.resample('A').last()
TBill_Adata[['DTB3']].tail()
# Out:
#             DTB3
# DATE
# 2018-12-31  2.40
# 2019-12-31  1.52
# 2020-12-31  0.09
# 2021-12-31  0.06
# 2022-12-31  4.30

# %% [markdown]
# #### Compute annual return for bonds:

# %%
TBill_Adata['returns'] = TBill_Adata['DTB3'] / 100
TBill_Adata = TBill_Adata.dropna()
print (TBill_Adata['returns'])
# Out:
# DATE
# 1993-12-31    0.0301
# 1994-12-31    0.0553
# 1995-12-31    0.0496
# 1996-12-31    0.0507
# 1997-12-31    0.0522
# 1998-12-31    0.0437
# 1999-12-31    0.0517
# 2000-12-31    0.0573
# 2001-12-31    0.0171
# 2002-12-31    0.0120
# 2003-12-31    0.0093
# 2004-12-31    0.0218
# 2005-12-31    0.0399
# 2006-12-31    0.0489
# 2007-12-31    0.0329
# 2008-12-31    0.0011
# 2009-12-31    0.0006
# 2010-12-31    0.0012
# 2011-12-31    0.0002
# 2012-12-31    0.0005
# 2013-12-31    0.0007
# 2014-12-31    0.0004
# 2015-12-31    0.0016
# 2016-12-31    0.0050
# 2017-12-31    0.0137
# 2018-12-31    0.0240
# 2019-12-31    0.0152
# 2020-12-31    0.0009
# 2021-12-31    0.0006
# 2022-12-31    0.0430
# Freq: A-DEC, Name: returns, dtype: float64

# %% [markdown]
# #### Compute average annual return and standard deviation of return for bonds:

# %%
TBill_mean_ret = float(TBill_Adata[['returns']].mean())
TBill_std_ret = float(TBill_Adata[['returns']].std())
print ("T-bill average return = %g%%, st. dev  = %g%%" % (100*TBill_mean_ret, 100*TBill_std_ret))
# Out:
# T-bill average return = 2.27067%, st. dev  = 2.12196%

# %% [markdown]
# #### Compute covariance matrix:

# %%
covMat = cov(array(SnP500_Adata[['returns']]),array(TBill_Adata[['returns']]),rowvar=0)
covMat
# Out:
# array([[0.03134404, 0.00017941],
#        [0.00017941, 0.00045027]])

# %% [markdown]
# #### Simulate portfolio:

# %%
v0 = 1000 # Initial capital
Ns = 5000 # Number of scenarios

# %%
mu = [SnP500_mean_ret, TBill_mean_ret] # Expected return
mu
# Out:
# [0.0909308592381406, 0.022706666666666674]

# %%
stockRet = ones(Ns)
bondsRet = ones(Ns)

# %%
scenarios = random.multivariate_normal(mu, covMat, Ns)
for year in range(1, 31):
    scenarios = random.multivariate_normal(mu, covMat, Ns)
    stockRet *= (1 + scenarios[:,0])
    bondsRet *= (1 + scenarios[:,1])

# %%
v30 = 0.5 * v0 * stockRet + 0.5 * v0 * bondsRet

# %%
hist, bins = histogram(v30, bins = 100)
positions = (bins[:-1] + bins[1:]) / 2
width = (bins[1] - bins[0]) * 0.8
plt.bar(positions, hist, width=width)
plt.xlabel('portfolio value after 30 years')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# # Simulation Example 4
#
# Compare two portfolios

# %%
# Compute portfolios by iterating through different combinations of weights
v30comp = []
for w in arange(0.2, 1.01, 0.2):
    v30comp += [w * v0 * stockRet + (1 - w) * v0 * bondsRet]

# %%
# Plot a histogram of the distribution of
# differences in outcomes for v30
# (Stratery 4 - Strategy 2)
v30d = v30comp[3] - v30comp[1]

# %%
hist, bins = histogram(v30d, bins = 50)
positions = (bins[:-1] + bins[1:]) / 2
width = (bins[1] - bins[0]) * 0.8
plt.bar(positions, hist, width=width)
plt.show()

# %%
# Compute number of elements in v30d that are > 0 and < 0 and compare
pos_count = (v30d > 0).sum()
neg_count = (v30d <= 0).sum()

print (u"""Strategy 4 was better in %d cases (%d%%)
Strategy 2 was better in %d cases (%d%%)
Difference = %d scenarios""" % (pos_count, round(100*(pos_count/Ns)), neg_count, round(100*(neg_count/Ns)), pos_count - neg_count))
# Out:
# Strategy 4 was better in 4754 cases (95%)
# Strategy 2 was better in 246 cases (5%)
# Difference = 4508 scenarios
